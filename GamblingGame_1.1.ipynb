# %%
# A simple high/low gambling game that saves earnings and losses


# imports the random package to use random function
import random
from rich.progress import Progress
import time

from nbformat.v3.nbbase import cast_str

myCash = int(1000)

print("WELCOME TO SAMS HIGH/LOW GAMBLING")
myName = input("What is your name? ")
# create "loading/status" bar
print("Accessing profile for " + myName + "...")
# print("Your cash balance is " + myCash + ".")

print(myCash)


while myCash >= 0:


    # print("You have " + "$" + cast_str(myCash) + " cash available.")

    # calculates earnings and losses
    count += 1
    myBet = int(input("How much money would you like to bet on this round? "))
    print(myBet)

    # generates a random number
    firstNumber = random.randint(1, 7777777)
    print("Your FIRST NUMBER is", firstNumber)

    # generates a random magic number
    randNumber = (random.randint(1, 7**7)) # generates a random number between 1 and 7^7
    digit_sum1 = sum(int(digit) for digit in str(randNumber))
    digit_sum2 = sum(int(digit) for digit in str(digit_sum1))
    MagicNumber = str(digit_sum2)
    print("Your MAGIC NUMBER is " + MagicNumber + ".")

    # collects choice
    myGuess = input("high or low?")
    print("Your GUESS is " + myGuess + "er" + ".")

    # draws another random number
    secondNumber = random.randint(1, 7777777)
    print("Your SECOND NUMBER is", secondNumber)

    # checks if high/low guess is correct

    if firstNumber < secondNumber and myGuess == "high":
        print("YOU WIN!")
        myCash += myBet
        print("Your NEW CASH BALANCE is", myCash)
    if firstNumber < secondNumber and myGuess == "low":
        print("YOU LOSE!")
        myCash -= myBet
        print("Your NEW CASH BALANCE is", myCash)
    if firstNumber > secondNumber and myGuess == "high":
        print("YOU LOSE!")
        myCash -= myCash
        print("Your NEW CASH BALANCE is", myCash)
    if firstNumber > secondNumber and myGuess == "low":
        print("YOU WIN!")
        myCash += myCash
        print("Your NEW CASH BALANCE is", myCash)
    if firstNumber == secondNumber:
        print("BONUS WIN")
        myCash += myBet * MagicNumber
        print("Your NEW CASH BALANCE is", myCash)
# Out:
# WELCOME TO SAMS HIGH/LOW GAMBLING
# Accessing profile for sam...
# 1000
# 500
# Your FIRST NUMBER is 2358719
# Your MAGIC NUMBER is 8.
# Your GUESS is higher.
# Your SECOND NUMBER is 4625909
# YOU WIN!
# Your NEW CASH BALANCE is 1500
# 578
# Your FIRST NUMBER is 1752235
# Your MAGIC NUMBER is 9.
# Your GUESS is higher.
# Your SECOND NUMBER is 3189922
# YOU WIN!
# Your NEW CASH BALANCE is 2078
# 2000
# Your FIRST NUMBER is 605295
# Your MAGIC NUMBER is 3.
# Your GUESS is higher.
# Your SECOND NUMBER is 3704810
# YOU WIN!
# Your NEW CASH BALANCE is 4078
# 4000
# Your FIRST NUMBER is 6239458
# Your MAGIC NUMBER is 7.
# Your GUESS is lower.
# Your SECOND NUMBER is 6260143
# YOU LOSE!
# Your NEW CASH BALANCE is 78
# 70
# Your FIRST NUMBER is 1291453
# Your MAGIC NUMBER is 9.
# Your GUESS is higher.
# Your SECOND NUMBER is 7377343
# YOU WIN!
# Your NEW CASH BALANCE is 148
# 100
# Your FIRST NUMBER is 6936438
# Your MAGIC NUMBER is 6.
# Your GUESS is lower.
# Your SECOND NUMBER is 6347005
# YOU WIN!
# Your NEW CASH BALANCE is 296
# 250
# Your FIRST NUMBER is 1166159
# Your MAGIC NUMBER is 3.
# Your GUESS is higher.
# Your SECOND NUMBER is 6035085
# YOU WIN!
# Your NEW CASH BALANCE is 546
# 540
# Your FIRST NUMBER is 6791120
# Your MAGIC NUMBER is 8.
# Your GUESS is lower.
# Your SECOND NUMBER is 6539798
# YOU WIN!
# Your NEW CASH BALANCE is 1092
# 1050
# Your FIRST NUMBER is 3775175
# Your MAGIC NUMBER is 7.
# Your GUESS is lower.
# Your SECOND NUMBER is 6658845
# YOU LOSE!
# Your NEW CASH BALANCE is 42
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 28
#      19 print(myCash)
#      22 while myCash >= 0:
#      23
#      24
#      25     # print("You have " + "$" + cast_str(myCash) + " cash available.")
#      26
#      27     # calculates earnings and losses
# ---> 28     myBet = int(input("How much money would you like to bet on this round? "))
#      29     print(myBet)
#      31     # generates a random number
#
# File ~\PycharmProjects\JupyterProject\.venv\Lib\site-packages\ipykernel\kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# File ~\PycharmProjects\JupyterProject\.venv\Lib\site-packages\ipykernel\kernelbase.py:1441, in Kernel._input_request(self, prompt, ident, parent, password)
#    1438 except KeyboardInterrupt:
#    1439     # re-raise KeyboardInterrupt, to truncate traceback
#    1440     msg = "Interrupted by user"
# -> 1441     raise KeyboardInterrupt(msg) from None
#    1442 except Exception:
#    1443     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
