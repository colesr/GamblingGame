# %%
# A simple high/low gambling game that saves earnings and losses


# imports the random package to use random function
import random
import sys
from rich.progress import Progress
import time

from nbformat.v3.nbbase import cast_str

myCash = int(1000)
startingCash = myCash # track starting amount for net summary

print("WELCOME TO SAMS HIGH/LOW GAMBLING")
myName = input("What is your name? ").capitalize()
# create "loading/status" bar
print("Accessing profile for " + myName + "...")
print("Cash available to wager: ",myCash, ".")

while myCash > 0:
    print("****************************************************************************")

    # collects adn validates bet amount
    myBet = int(input("How much money would you like to bet on this round? "))
    if myBet > myCash:
        print("You do not have enough money to bet that amount. Please reduce bet amount.")
        myBet = myCash
    if myBet <= 0:
        print("Bet must be greater than $0. Please try again.")
        continue
    print("You have a cash balance of", myCash, "and are betting", myBet,".")


    # generates a random number
    firstNumber = random.randint(1, 7777777)
    print("Your FIRST NUMBER is", firstNumber)

    # generates a random magic number
    randNumber = (random.randint(1, 7**7)) # generates a random number between 1 and 7^7
    digit_sum1 = sum(int(digit) for digit in str(randNumber))
    digit_sum2 = sum(int(digit) for digit in str(digit_sum1))
    MagicNumber = digit_sum2 #keep as int for multiplier
    print("Your MAGIC NUMBER: ")
    print(MagicNumber)

    # collects choice
    myGuess = input("high or low? ").strip().lower()
    print("Your GUESS is " + myGuess + "er.")

    # draws another random number
    secondNumber = random.randint(1, 7777777)
    print("Your SECOND NUMBER is", secondNumber)

    # checks if high/low guess is correct and updates cash

    if firstNumber < secondNumber and myGuess == "high":
        print("YOU WIN!", myBet)
        myCash += myBet
        print("Your NEW CASH BALANCE is", myCash)
        print("Net change from start: $", myCash - startingCash)
    if firstNumber < secondNumber and myGuess == "low":
        print("YOU LOSE!", myBet)
        myCash -= myBet
        print("Your NEW CASH BALANCE is", myCash)
        print("Net change from start: $", myCash - startingCash)
    if firstNumber > secondNumber and myGuess == "high":
        print("YOU LOSE!", myBet)
        myCash -= myBet
        print("Your NEW CASH BALANCE is", myCash)
        print("Net change from start: $", myCash - startingCash)
    if firstNumber > secondNumber and myGuess == "low":
        print("YOU WIN!", myBet)
        myCash += myBet
        print("Your NEW CASH BALANCE is", myCash)
        print("Net change from start: $", myCash - startingCash)
    if MagicNumber == abs(firstNumber - secondNumber):
        print("BONUS WIN")
        myCash += myBet * MagicNumber
        print("Your NEW CASH BALANCE + BONUS is", myCash)
        print("Net change from start: $", myCash - startingCash)
    addCash = input("Would you like to add cash? ")
    if addCash == "yes":
        addCashAmt = int(input("How much money would you like to add? $"))
        myCash += int(addCashAmt)
        startingCash += addCashAmt # adjust baseline so net stays accurate
        print("Your NEW CASH BALANCE is $", myCash)

    elif addCash == 'no':
        keepPlaying = input("Would you like to play again? ").strip().lower()
        if keepPlaying =="yes":
            continue
        elif keepPlaying == "no":
            print("Thank you for playing, ", myName + "! Final balance: $", myCash)
            sys.exit()
# Out:
# WELCOME TO SAMS HIGH/LOW GAMBLING
# Accessing profile for Sam...
# Cash available to wager:  1000 .
# ****************************************************************************
# You have a cash balance of 1000 and are betting 500 .
# Your FIRST NUMBER is 2075733
# Your MAGIC NUMBER:
# 10
# Your GUESS is higher.
# Your SECOND NUMBER is 6739002
# YOU WIN! 500
# Your NEW CASH BALANCE is 1500
# Net change from start: $ 500
# ****************************************************************************
# You have a cash balance of 1500 and are betting 1500 .
# Your FIRST NUMBER is 3067984
# Your MAGIC NUMBER:
# 7
# Your GUESS is higher.
# Your SECOND NUMBER is 6798108
# YOU WIN! 1500
# Your NEW CASH BALANCE is 3000
# Net change from start: $ 2000
# ****************************************************************************
# You have a cash balance of 3000 and are betting 3000 .
# Your FIRST NUMBER is 802843
# Your MAGIC NUMBER:
# 10
# Your GUESS is higher.
# Your SECOND NUMBER is 100860
# YOU LOSE! 3000
# Your NEW CASH BALANCE is 0
# Net change from start: $ -1000
# Your NEW CASH BALANCE is $ 2000
# ****************************************************************************
# You have a cash balance of 2000 and are betting 1500 .
# Your FIRST NUMBER is 1117264
# Your MAGIC NUMBER:
# 6
# Your GUESS is higher.
# Your SECOND NUMBER is 2392703
# YOU WIN! 1500
# Your NEW CASH BALANCE is 3500
# Net change from start: $ 500
# ****************************************************************************
# You have a cash balance of 3500 and are betting 3500 .
# Your FIRST NUMBER is 3777993
# Your MAGIC NUMBER:
# 9
# Your GUESS is higher.
# Your SECOND NUMBER is 7610317
# YOU WIN! 3500
# Your NEW CASH BALANCE is 7000
# Net change from start: $ 4000
# ****************************************************************************
# You have a cash balance of 7000 and are betting 7000 .
# Your FIRST NUMBER is 5613955
# Your MAGIC NUMBER:
# 10
# Your GUESS is lower.
# Your SECOND NUMBER is 4067013
# YOU WIN! 7000
# Your NEW CASH BALANCE is 14000
# Net change from start: $ 11000
# ****************************************************************************
# You have a cash balance of 14000 and are betting 11000 .
# Your FIRST NUMBER is 2853563
# Your MAGIC NUMBER:
# 5
# Your GUESS is higher.
# Your SECOND NUMBER is 5243436
# YOU WIN! 11000
# Your NEW CASH BALANCE is 25000
# Net change from start: $ 22000
# ****************************************************************************
# You have a cash balance of 25000 and are betting 25000 .
# Your FIRST NUMBER is 953261
# Your MAGIC NUMBER:
# 4
# Your GUESS is higher.
# Your SECOND NUMBER is 4878075
# YOU WIN! 25000
# Your NEW CASH BALANCE is 50000
# Net change from start: $ 47000
# Thank you for playing,  Sam! Final balance: $ 50000
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\colec\PycharmProjects\JupyterProject\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3707: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
