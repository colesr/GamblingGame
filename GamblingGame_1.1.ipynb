# %%
# A simple high/low gambling game that saves earnings and losses


# imports the random package to use random function
import random
import sys
from rich.progress import Progress
import time

from nbformat.v3.nbbase import cast_str

myCash = int(1000)

print("WELCOME TO SAMS HIGH/LOW GAMBLING")
myName = input("What is your name? ").capitalize()
# create "loading/status" bar
print("Accessing profile for " + myName + "...")
print("Cash available to wager: ",myCash, ".")

while myCash > 0:
    print("****************************************************************************")

    addCash = input("Would you like to add cash? ")
    if addCash == "yes":
        addCashAmt = input("How much money would you like to add? ")
        myCash += int(addCashAmt)
        print("Your NEW CASH BALANCE is", myCash)

    # calculates earnings and losses
    myBet = int(input("How much money would you like to bet on this round? "))
    print("You have a cash balance of ", myCash, " and are betting ", myBet, ".")

    # generates a random number
    firstNumber = random.randint(1, 7777777)
    print("Your FIRST NUMBER is", firstNumber)

    # generates a random magic number
    randNumber = (random.randint(1, 7**7)) # generates a random number between 1 and 7^7
    digit_sum1 = sum(int(digit) for digit in str(randNumber))
    digit_sum2 = sum(int(digit) for digit in str(digit_sum1))
    MagicNumber = str(digit_sum2)
    print("Your MAGIC NUMBER is " + MagicNumber + ".")

    # collects choice
    myGuess = input("high or low?")
    print("Your GUESS is " + myGuess + "er" + ".")

    # draws another random number
    secondNumber = random.randint(1, 7777777)
    print("Your SECOND NUMBER is", secondNumber)

    # checks if high/low guess is correct

    if firstNumber < secondNumber and myGuess == "high":
        print("YOU WIN!")
        myCash += myBet
        print("Your NEW CASH BALANCE is", myCash)
    if firstNumber < secondNumber and myGuess == "low":
        print("YOU LOSE!")
        myCash -= myBet
        print("Your NEW CASH BALANCE is", myCash)
    if firstNumber > secondNumber and myGuess == "high":
        print("YOU LOSE!")
        myCash -= myBet
        print("Your NEW CASH BALANCE is", myCash)
    if firstNumber > secondNumber and myGuess == "low":
        print("YOU WIN!")
        myCash += myBet
        print("Your NEW CASH BALANCE is", myCash)
    if firstNumber == secondNumber:
        print("BONUS WIN")
        myCash += (myBet * MagicNumber)
        print("Your NEW CASH BALANCE is", myCash)


#elif addCash == 'no':
#    print("Thank you for playing!")
#    sys.exit(1)
# Out:
# WELCOME TO SAMS HIGH/LOW GAMBLING
# Accessing profile for Sam...
# Cash available to wager:  1000 .
# ****************************************************************************
# Your NEW CASH BALANCE is 101000
# You have a cash balance of  101000  and are betting  50000 .
# Your FIRST NUMBER is 6757489
# Your MAGIC NUMBER is 10.
# Your GUESS is lower.
# Your SECOND NUMBER is 2312497
# YOU WIN!
# Your NEW CASH BALANCE is 151000
# ****************************************************************************
# You have a cash balance of  151000  and are betting  150000 .
# Your FIRST NUMBER is 29500
# Your MAGIC NUMBER is 6.
# Your GUESS is higher.
# Your SECOND NUMBER is 699308
# YOU WIN!
# Your NEW CASH BALANCE is 301000
# ****************************************************************************
# You have a cash balance of  301000  and are betting  300000 .
# Your FIRST NUMBER is 1171830
# Your MAGIC NUMBER is 8.
# Your GUESS is higher.
# Your SECOND NUMBER is 6500867
# YOU WIN!
# Your NEW CASH BALANCE is 601000
# ****************************************************************************
# Your NEW CASH BALANCE is 701000
# You have a cash balance of  701000  and are betting  7000000 .
# Your FIRST NUMBER is 1858255
# Your MAGIC NUMBER is 5.
# Your GUESS is higher.
# Your SECOND NUMBER is 2416127
# YOU WIN!
# Your NEW CASH BALANCE is 7701000
# ****************************************************************************
# You have a cash balance of  7701000  and are betting  7701000 .
# Your FIRST NUMBER is 6382624
# Your MAGIC NUMBER is 10.
# Your GUESS is lower.
# Your SECOND NUMBER is 685538
# YOU WIN!
# Your NEW CASH BALANCE is 15402000
# ****************************************************************************
# You have a cash balance of  15402000  and are betting  15402000 .
# Your FIRST NUMBER is 6805171
# Your MAGIC NUMBER is 3.
# Your GUESS is lower.
# Your SECOND NUMBER is 575902
# YOU WIN!
# Your NEW CASH BALANCE is 30804000
# ****************************************************************************
# You have a cash balance of  30804000  and are betting  30804000 .
# Your FIRST NUMBER is 3678505
# Your MAGIC NUMBER is 2.
# Your GUESS is lower.
# Your SECOND NUMBER is 2770669
# YOU WIN!
# Your NEW CASH BALANCE is 61608000
# ****************************************************************************
# You have a cash balance of  61608000  and are betting  61608000 .
# Your FIRST NUMBER is 5860447
# Your MAGIC NUMBER is 3.
# Your GUESS is lower.
# Your SECOND NUMBER is 6173317
# YOU LOSE!
# Your NEW CASH BALANCE is 0
