# %%
AI and ML driven solution that supports business continuity/disaster recovery planning through highly realistic simulated disaster scenario journey execution:

App called “Disastr”

Uses ML analytical engine to simulate hyper-realistic "worst-case scenarios," allowing business leadership to prioritize safely stress-testing company’s financial health and business continuity protocols

Leadership can modify and tailor the entire experience individually and broadly across different organizations for experiences that are unique to the team and role, creating a highly valuable and unique learning experience

Fundamentally, the app through highly customizable experiences target pain points and challenges within the organization, measuring the company's financial impact of such disasters and the cost of different users’ behaviors in the face of stressful, unknown work events

What is costly

What saves the company money

What can be implemented across different teams more broadly

User has profile set up and credentials shared, which they use to log in after downloading this app.

App Disaster Simulation Journey:

The app has an interface that is like a VM on their personal phone.

All Disastr events take place within the dedicated environment and have absolutely no effect on the users’ day-to-day software

An example “Event:”

Suddenly, with no prior warning, all of the files accessible within the Disastr platform are “locked” by hackers that were able to penetrate the Company’s IT Security protocols

Users experience a very realistic simulation of such an event, where all of their files are locked, cannot open any applications

Users are forced to rely on their training in disaster recovery and business continuity by pivoting their ways of working and communication quickly to maintain business expectations

The app collects lots of data points on how participants navigate their work and behaviors during a high-stress event with lots of unknowns

Work in progress – wireframe mock-up below

# %% [markdown]
# ![image.png](attachment:7e3b7cb5-7400-4fa2-a411-eeb006f0015b.png)
