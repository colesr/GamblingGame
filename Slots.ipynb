# %%
import random

print("Welcome to Sam's Slots")
name = input("What is your name?")
print("Hello " + name)
print("Loading account information...")
cashBal = 1000
print("Account balance: ", cashBal)

# play = input("What slot would you like to play 1, 2 3?")
# print("You chose " + play)




def slots(cashBal):

    addCash = input("Would you like to add cash? yes/no")
    if addCash == "yes":
        addCashAmt = int(input("How much would you like to add?"))
        cashBal += addCashAmt
        print("You chose to add " + str(addCashAmt) + " and you have a total balance of " + str(cashBal) + "")
    else:
        addCashAmt = 0
        print("You chose not to add cash")

    while cashBal >= 0:

        bet = int(input("How much money do you want to bet?"))
        print("You bet " + str(bet))

        a = random.randint(1, 9)
        b = random.randint(1, 9)
        c = random.randint(1, 9)
        print(a, b, c)

        if a == b == c:
            print("You won BIG!")
            winnings = bet ** bet
            cashBal += bet ** bet
            print("You won " + str(winnings) + " and your new balance is " + str(cashBal))
            game = input("Play again? yes/no")
            if game == "yes":
                continue
            else:
                break
        elif a == b or a == c or b == c:
            print("You won!")
            winnings = bet ** bet
            cashBal += bet ** bet
            print("You won " + str(winnings) + " and your new balance is " + str(cashBal))
            game = input("Play again? yes/no")
            if game == "yes":
                continue
            else:
                break
        else:
            print("You lost!")
            cashBal -= bet
            print("You lost " + str(bet) + " and your new balance is " + str(cashBal))
            game = input("Play again? yes/no")
            if game == "yes":
                continue
            else:
                break
print(slots(cashBal))



# d = input("Would you like to add cash?")
# print("You chose " + d)
# Out:
# Welcome to Sam's Slots
# Hello sam
# Loading account information...
# Account balance:  1000
# You chose to add 2500 and you have a total balance of 3500
# You bet 350
# 9 1 9
# You won!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 66
#      64             else:
#      65                 break
# ---> 66 print(slots(cashBal))
#      70 # d = input("Would you like to add cash?")
#      71 # print("You chose " + d)
#
# Cell In[23], line 51, in slots(cashBal)
#      49 winnings = bet ** bet
#      50 cashBal += bet ** bet
# ---> 51 print("You won " + winnings + " and your new balance is " + str(cashBal))
#      52 game = input("Play again? yes/no")
#      53 if game == "yes":
#
# TypeError: can only concatenate str (not "int") to str
